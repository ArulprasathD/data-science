# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = np.array([[1], [2], [3], [4], [5]]) 
y = np.array([30000, 35000, 40000, 45000, 50000])  


model = LinearRegression()
model.fit(X,y)

# result = model.predict([[6]])
print('linear regression : ',model.predict([[6]]))
# Out:
# linear regression :  [55000.]

# %%
x_train = np.array([[1],[2],[3],[4],[5]])
y_train = np.array([5000,10000,15000,20000,25000])

model = LinearRegression()
model.fit(x_train,y_train)

x_test = np.array([[6],[7],[8]])

y_pedt = model.predict(x_test)

print('test :',x_test.flatten())
print('predict :',y_pedt)
# Out:
# test : [6 7 8]
# predict : [30000. 35000. 40000.]
